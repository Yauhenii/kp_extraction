# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers -q
# !pip install sentencepiece -q

# %% [markdown]
# # Code of generate_kp(...) from generate_kp.py

# %%
import torch
import pandas as pd
from transformers import PegasusTokenizer, PegasusForConditionalGeneration

# generate kp from, arg and topic
def generate_kp(
    arg_topic_df: pd.DataFrame,
    model: PegasusForConditionalGeneration,
    tokenizer: PegasusTokenizer,
    device: str,
    use_topic: bool = False,
    batch_size: int = 16,
    verbose: bool = False,
) -> pd.DataFrame:
    """
    arg_topic_df: df with 'arg' and 'topic' columns
    model: pretrained model
    tokenizer: Pegasus Tokenizer
    device: 'cpu'/'gpu'
    use_topic: use arg+topic to predict kp
    batch_size: batch size (int)
    verbose: print intermediate steps
    ________
    return: df with generated kp,arg, and topic(if available)
    """
    feature_df = arg_topic_df.copy()
    if use_topic:
        feature_df["feature"] = feature_df["arg"] + feature_df["topic"]
    else:
        feature_df["feature"] = feature_df["arg"]

    features = list(feature_df["feature"])
    features_count = len(features)
    batch_count = features_count // batch_size + 1 if (features_count % batch_size)!=0 else 0

    curr_batch_size = 0
    targets = []

    model.to(device)

    with torch.no_grad():
        for batch_id in range(batch_count):
            if (batch_id + 1) * batch_size > features_count:
                curr_batch_size = features_count - batch_id * batch_size
            else:
                curr_batch_size = batch_size

            if verbose:
                print(f"batch_id: {batch_id}")
                print(f"curr_batch_size: {curr_batch_size}")
                print("Tokenizing...")
            tokenized_features = tokenizer(
                features[
                    batch_id * batch_size : batch_id * batch_size + curr_batch_size
                ],
                truncation=True,
                padding="longest",
                return_tensors="pt",
            ).to(device)
            if verbose:
                print("Generating...")
            tokenized_targets = model.generate(**tokenized_features, num_beams=6)
            if verbose:
                print("Decoding...")
            targets += tokenizer.batch_decode(
                tokenized_targets,
                skip_special_tokens=True,
            )

    feature_df["kp_gen"] = targets
    return feature_df

# %% [markdown]
# # Generate

# %%
dataset_path = '/content/drive/MyDrive/Colab Notebooks/nlp/dataset/'
arg_df = pd.read_csv(dataset_path + 'dataset_austin_sentences.csv')

# %%
arg_df = arg_df.rename(columns = {'text':'arg'})

# %%
folder_path = "/content/drive/MyDrive/Colab Notebooks/nlp/"
model_path = folder_path + "EMNLP_folder_4/headline_model/"

tokenizer = PegasusTokenizer.from_pretrained('google/pegasus-xsum')
model = PegasusForConditionalGeneration.from_pretrained(model_path,local_files_only=True)

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
device
# Out:
# 'cuda'

# %% [markdown]
# ### Try small subset

# %%
batch_size = 2

# %%
small_arg_df = arg_df.head()
small_arg_df
# Out:
#    id                                                arg  district  year
# 0   1  Dissatisfied traffic and with traffic, timing ...         7  2016
# 1   2              EXTREMELY dissatisfied with cit govt.         7  2016
# 2   3  interfering in local businesses (Uber/Lyft, in...         7  2016
# 3   4  Also, extremely dissatisfied with all the free...         7  2016
# 4   5  I'm very dissatisfied with the liberal leaning...         7  2016

# %%
small_kp_gen_df = generate_kp(
        small_arg_df,
        model=model,
        device=device,
        tokenizer=tokenizer,
        batch_size=batch_size,
        verbose=True
    )
# Out:
# batch_id: 0
# curr_batch_size: 2
# Tokenizing...
# Generating...
# Decoding...
# batch_id: 1
# curr_batch_size: 2
# Tokenizing...
# Generating...
# Decoding...
# batch_id: 2
# curr_batch_size: 1
# Tokenizing...
# Generating...
# Decoding...

# %% [markdown]
# ### Full set

# %%
arg_df.head()
# Out:
#    id                                                arg  district  year
# 0   1  Dissatisfied traffic and with traffic, timing ...         7  2016
# 1   2              EXTREMELY dissatisfied with cit govt.         7  2016
# 2   3  interfering in local businesses (Uber/Lyft, in...         7  2016
# 3   4  Also, extremely dissatisfied with all the free...         7  2016
# 4   5  I'm very dissatisfied with the liberal leaning...         7  2016

# %%
arg_df.shape
# Out:
# (6274, 4)

# %% [markdown]
# #### Choose best batch size

# %%
# %%time
kp_gen_df = generate_kp(
        arg_df[0:16*8],
        model=model,
        device=device,
        tokenizer=tokenizer,
        batch_size=8,
    )
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-5983bdc014e5> in <module>()
# ----> 1 get_ipython().run_cell_magic('time', '', 'kp_gen_df = generate_kp(\n        arg_df[0:16*8],\n        model=model,\n        device=device,\n        tokenizer=tokenizer,\n        batch_size=8,\n    )')
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py in run_cell_magic(self, magic_name, line, cell)
#    2115             magic_arg_s = self.var_expand(line, stack_depth)
#    2116             with self.builtin_trap:
# -> 2117                 result = fn(magic_arg_s, cell)
#    2118             return result
#    2119
#
# <decorator-gen-53> in time(self, line, cell, local_ns)
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     186     # but it's overkill for just that one bit of state.
#     187     def magic_deco(arg):
# --> 188         call = lambda f, *a, **k: f(*a, **k)
#     189
#     190         if callable(arg):
#
# /usr/local/lib/python3.7/dist-packages/IPython/core/magics/execution.py in time(self, line, cell, local_ns)
#    1191         else:
#    1192             st = clock2()
# -> 1193             exec(code, glob, local_ns)
#    1194             end = clock2()
#    1195             out = None
#
# <timed exec> in <module>()
#
# <ipython-input-3-d60b58176b0b> in generate_kp(arg_topic_df, model, tokenizer, device, use_topic, batch_size, verbose)
#      68             )
#      69
# ---> 70     feature_df["kp_gen"] = targets
#      71     return feature_df
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    3610         else:
#    3611             # set column
# -> 3612             self._set_item(key, value)
#    3613
#    3614     def _setitem_slice(self, key: slice, value):
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _set_item(self, key, value)
#    3782         ensure homogeneity.
#    3783         """
# -> 3784         value = self._sanitize_column(value)
#    3785
#    3786         if (
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in _sanitize_column(self, value)
#    4507
#    4508         if is_list_like(value):
# -> 4509             com.require_length_match(value, self.index)
#    4510         return sanitize_array(value, self.index, copy=True, allow_2d=True)
#    4511
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/common.py in require_length_match(data, index)
#     530     if len(data) != len(index):
#     531         raise ValueError(
# --> 532             "Length of values "
#     533             f"({len(data)}) "
#     534             "does not match length of index "
#
# ValueError: Length of values (0) does not match length of index (128)

# %%
# %%time
kp_gen_df = generate_kp(
        arg_df[0:8*16],
        model=model,
        device=device,
        tokenizer=tokenizer,
        batch_size=16,
    )

# %%
# %%time
kp_gen_df = generate_kp(
        arg_df[0:4*32],
        model=model,
        device=device,
        tokenizer=tokenizer,
        batch_size=32,
    )

# %%
# %%time
kp_gen_df = generate_kp(
        arg_df[0:2*64],
        model=model,
        device=device,
        tokenizer=tokenizer,
        batch_size=64,
    )

# %% [markdown]
# #### Generate

# %%
batch_size = 32

# %%
# %%time
kp_gen_df = generate_kp(
        arg_df,
        model=model,
        device=device,
        tokenizer=tokenizer,
        batch_size=batch_size,
    )
# Out:
# CPU times: user 7min 49s, sys: 1.81 s, total: 7min 51s
# Wall time: 7min 52s

# %%
kp_gen_df.shape
# Out:
# (6274, 6)

# %%
kp_gen_df.head()
# Out:
#    id                                                arg  district  year  \
# 0   1  Dissatisfied traffic and with traffic, timing ...         7  2016
# 1   2              EXTREMELY dissatisfied with cit govt.         7  2016
# 2   3  interfering in local businesses (Uber/Lyft, in...         7  2016
# 3   4  Also, extremely dissatisfied with all the free...         7  2016
# 4   5  I'm very dissatisfied with the liberal leaning...         7  2016
#
#                                              feature  \
# 0  Dissatisfied traffic and with traffic, timing ...
# 1              EXTREMELY dissatisfied with cit govt.
# 2  interfering in local businesses (Uber/Lyft, in...
# 3  Also, extremely dissatisfied with all the free...
# 4  I'm very dissatisfied with the liberal leaning...
#
#                                               kp_gen
# 0  Traffic is causing a strain on the cities' res...
# 1                  Citizens have a right not to vote
# 2  Hiring a private hire company is financially b...
# 3  Government intervention has the risk of insert...
# 4  People should choose for themselves whether or...

# %%
kp_gen_df.to_csv(dataset_path + 'dataset_austin_sentences_enigma_predictions_2.csv')

# %% [markdown]
# # Compare current and previous predictions

# %%
prev_kp_gen_df = pd.read_csv(dataset_path + 'dataset_austin_sentences_enigma_predictions.csv')
prev_kp_gen_df.head()
# Out:
#    Unnamed: 0                                               text  \
# 0           0  Dissatisfied traffic and with traffic, timing ...
# 1           1              EXTREMELY dissatisfied with cit govt.
# 2           2  interfering in local businesses (Uber/Lyft, in...
# 3           3  Also, extremely dissatisfied with all the free...
# 4           4  I'm very dissatisfied with the liberal leaning...
#
#                                       key_point_pred  district  year
# 0  Traffic is causing a strain on the cities' res...         7  2016
# 1                  Citizens have a right not to vote         7  2016
# 2  Hiring a private hire company is financially b...         7  2016
# 3  Government intervention has the risk of insert...         7  2016
# 4  People should choose for themselves whether or...         7  2016

# %%
prev_kp_gen_df = prev_kp_gen_df.rename(columns={'Unnamed: 0':'id'})

# %%
prev_kp_gen_df.head()
# Out:
#    id                                               text  \
# 0   0  Dissatisfied traffic and with traffic, timing ...
# 1   1              EXTREMELY dissatisfied with cit govt.
# 2   2  interfering in local businesses (Uber/Lyft, in...
# 3   3  Also, extremely dissatisfied with all the free...
# 4   4  I'm very dissatisfied with the liberal leaning...
#
#                                       key_point_pred  district  year
# 0  Traffic is causing a strain on the cities' res...         7  2016
# 1                  Citizens have a right not to vote         7  2016
# 2  Hiring a private hire company is financially b...         7  2016
# 3  Government intervention has the risk of insert...         7  2016
# 4  People should choose for themselves whether or...         7  2016

# %%
prev_kp_gen_df['id']=prev_kp_gen_df['id']+1
prev_kp_gen_df.head()
# Out:
#    id                                               text  \
# 0   1  Dissatisfied traffic and with traffic, timing ...
# 1   2              EXTREMELY dissatisfied with cit govt.
# 2   3  interfering in local businesses (Uber/Lyft, in...
# 3   4  Also, extremely dissatisfied with all the free...
# 4   5  I'm very dissatisfied with the liberal leaning...
#
#                                       key_point_pred  district  year
# 0  Traffic is causing a strain on the cities' res...         7  2016
# 1                  Citizens have a right not to vote         7  2016
# 2  Hiring a private hire company is financially b...         7  2016
# 3  Government intervention has the risk of insert...         7  2016
# 4  People should choose for themselves whether or...         7  2016

# %%
kp_gen_df.set_index('id')
prev_kp_gen_df.set_index('id')
# Out:
#                                                    text  \
# id
# 1     Dissatisfied traffic and with traffic, timing ...
# 2                 EXTREMELY dissatisfied with cit govt.
# 3     interfering in local businesses (Uber/Lyft, in...
# 4     Also, extremely dissatisfied with all the free...
# 5     I'm very dissatisfied with the liberal leaning...
# ...                                                 ...
# 6270                You to need to pay teachers better.
# 6271  This city is too expensive to live in on the s...
# 6272  Austin Electric company is a monopoly who trea...
# 6273  My $200 deposit is being held hostage by the c...
# 6274  You will never make everyone happy, so do what...
#
#                                          key_point_pred  district  year
# id
# 1     Traffic is causing a strain on the cities' res...         7  2016
# 2                     Citizens have a right not to vote         7  2016
# 3     Hiring a private hire company is financially b...         7  2016
# 4     Government intervention has the risk of insert...         7  2016
# 5     People should choose for themselves whether or...         7  2016
# ...                                                 ...       ...   ...
# 6270    Teachers are essential to develop social skills         3  2017
# 6271              Parents are not qualified as teachers         3  2017
# 6272  Electricity is a necessity and should be provi...         3  2017
# 6273  A lot of people are losing their jobs because ...         3  2017
# 6274  People should choose for themselves whether or...         7  2017
#
# [6274 rows x 4 columns]

# %%
merged_df = pd.merge(kp_gen_df, prev_kp_gen_df, left_index=True, right_index=True)
merged_df.head()
# Out:
#    id_x                                                arg  district_x  \
# 0     1  Dissatisfied traffic and with traffic, timing ...           7
# 1     2              EXTREMELY dissatisfied with cit govt.           7
# 2     3  interfering in local businesses (Uber/Lyft, in...           7
# 3     4  Also, extremely dissatisfied with all the free...           7
# 4     5  I'm very dissatisfied with the liberal leaning...           7
#
#    year_x                                            feature  \
# 0    2016  Dissatisfied traffic and with traffic, timing ...
# 1    2016              EXTREMELY dissatisfied with cit govt.
# 2    2016  interfering in local businesses (Uber/Lyft, in...
# 3    2016  Also, extremely dissatisfied with all the free...
# 4    2016  I'm very dissatisfied with the liberal leaning...
#
#                                               kp_gen  id_y  \
# 0  Traffic is causing a strain on the cities' res...     1
# 1                  Citizens have a right not to vote     2
# 2  Hiring a private hire company is financially b...     3
# 3  Government intervention has the risk of insert...     4
# 4  People should choose for themselves whether or...     5
#
#                                                 text  \
# 0  Dissatisfied traffic and with traffic, timing ...
# 1              EXTREMELY dissatisfied with cit govt.
# 2  interfering in local businesses (Uber/Lyft, in...
# 3  Also, extremely dissatisfied with all the free...
# 4  I'm very dissatisfied with the liberal leaning...
#
#                                       key_point_pred  district_y  year_y
# 0  Traffic is causing a strain on the cities' res...           7    2016
# 1                  Citizens have a right not to vote           7    2016
# 2  Hiring a private hire company is financially b...           7    2016
# 3  Government intervention has the risk of insert...           7    2016
# 4  People should choose for themselves whether or...           7    2016

# %%
len(merged_df[(merged_df['kp_gen']!=merged_df['key_point_pred'])])
# Out:
# 18
