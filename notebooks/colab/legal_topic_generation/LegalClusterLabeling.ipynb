# %%
# !nvidia-smi
# Out:
# Wed Jun 15 17:21:58 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   67C    P0    30W /  70W |   4458MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# +-----------------------------------------------------------------------------+

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install transformers -q
# !pip install sentencepiece -q
# !pip install rouge_score -q

# %%
import pandas as pd
import random as rn
import numpy as np
import torch
import nltk
from collections import OrderedDict
from transformers import set_seed, PegasusTokenizer, PegasusForConditionalGeneration

# %%
# Setting seed
set_seed(321)
rn.seed(321)
np.random.seed(321)
torch.manual_seed(321)
torch.cuda.manual_seed(321)
device = 'cuda' if torch.cuda.is_available() else 'cpu'
nltk.download('punkt')
print(device)
# Out:
# cuda
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tokenizer = PegasusTokenizer.from_pretrained('google/pegasus-xsum')
model = PegasusForConditionalGeneration.from_pretrained('google/pegasus-xsum')

# %%
def summarize(args:list,delim:str=". ")->str:
  paragraph = delim.join(args)
  tokenized_paragraph = tokenizer(paragraph, return_tensors="pt").to(device)
  tokenized_output = model.generate(**tokenized_paragraph)
  detokenized_output = tokenizer.batch_decode(tokenized_output, skip_special_tokens=True)
  return detokenized_output[0]

def get_topic(args:list, use_unique=False)->str:
  unique_args = args if not use_unique else list(OrderedDict.fromkeys(args))
  max_count = 5
  summaries = []
  args_count = 0
  while(True):
    args_count = len(unique_args)
    print(args_count)
    if(args_count>max_count):
      summaries = []
      buckets_count = int(np.ceil(args_count/max_count))
      for i in range(buckets_count):
        if (i+1)*max_count>args_count:
          summaries.append(summarize(unique_args[i*max_count:args_count]))
        else:
          summaries.append(summarize(unique_args[i*max_count:(i+1)*max_count]))
      unique_args = summaries if not use_unique else list(OrderedDict.fromkeys(summaries))
    else:
      return summarize(unique_args)

# %% [markdown]
# # Read data

# %%
to_read_path = 'drive/MyDrive/Colab Notebooks/nlp/legal dataset/data/10_clusters.csv'
clustered_df = pd.read_csv(to_read_path)
clustered_df = clustered_df[['cluster_id','sentences']]
clustered_df.head()
# Out:
#    cluster_id                                          sentences
# 0           2  It recalls both its own findings and those of ...
# 1           2  This is demonstrated in other cases pending be...
# 2           2  Publication was also necessary to protect the ...
# 3           2  In the present case,\r\nthere was a formidable...
# 4           2  It was therefore not empowered to take evidenc...

# %% [markdown]
# # Group

# %%
grouped_df = clustered_df.groupby('cluster_id')
grouped_df.count()
# Out:
#             sentences
# cluster_id
# 0                 325
# 1                 278
# 2                 198
# 3                 113
# 4                 244
# 5                  36
# 6                  96
# 7                  79
# 8                  72
# 9                 119

# %% [markdown]
# # Do Labeling

# %%
model.to(device)
print('')

# %%
# %%time

topics = []

for id in range(10):
  result = get_topic(grouped_df.get_group(id)['sentences'].tolist())
  topics.append(result)
  print(result)
# Out:
# 325
# 65
# 13
# 3
# A round-up of interesting court cases from the UK and around the world this week:
# 278
# 56
# 12
# 3
# A complaint has been made to the European Court of Human Rights (ECHR) against the Archbishop of Canterbury, the Most Reverend Justin Welby, on the grounds that he has failed to fulfil his obligations under the European Convention on Human Rights.
# 198
# 40
# 8
# 2
# Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair
# 113
# 23
# 5
# The European Court of Human Rights (ECHR) has upheld the decision of the St Plten Regional Court to release on bail Ahmet Sadik, who had been arrested for drinking and driving.
# 244
# 49
# 10
# 2
# The European Court of Human Rights (ECHR) has ruled in favour of the Turkish government in a case brought by the opposition Republican People's Party (CHP) against the Turkish authorities over the use of torture and other forms of ill-treatment in police custody.
# 36
# 8
# 2
# The Court of Justice of the European Union (CJEU) has ruled that the European Court of Human Rights (ECHR) has jurisdiction to hear a case brought by the UK against the European Union under the European Convention on Human Rights.
# 96
# 20
# 4
# The European Court of Human Rights (ECHR) has ruled that the European Convention on Human Rights (ECHR) does not apply to the Republic of Ireland.
# 79
# 16
# 4
# The European Court of Human Rights (ECHR) has upheld a decision by the Court of Justice of the European Union (CJEU) that the right to a fair trial under the European Convention on Human Rights (ECHR) was not infringed by a decision by the European Court of Justice (ECJ) to
# 72
# 15
# 3
# The European Court of Human Rights (ECHR) has dismissed an appeal against the decision of the Bulgarian Supreme Court to uphold the so-called "unlawful intercourse" rule in the Bulgarian Marriage Act.
# 119
# 24
# 5
# The European Court of Aupair Aupair Human Rights (ECHR) has upheld a lower court's decision to dismiss a case brought by a Turkish Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair
# CPU times: user 6min 41s, sys: 949 ms, total: 6min 42s
# Wall time: 6min 43s

# %%
clustered_topic_df = clustered_df.join(pd.Series(topics)[clustered_df['cluster_id']].to_frame("topic").reset_index())
assert (clustered_topic_df['cluster_id']==clustered_topic_df['index']).all()
clustered_topic_df = clustered_topic_df[['cluster_id','sentences','topic']]

# %%
clustered_topic_df.head()
# Out:
#    cluster_id                                          sentences  \
# 0           2  It recalls both its own findings and those of ...
# 1           2  This is demonstrated in other cases pending be...
# 2           2  Publication was also necessary to protect the ...
# 3           2  In the present case,\r\nthere was a formidable...
# 4           2  It was therefore not empowered to take evidenc...
#
#                                                topic
# 0  Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# 1  Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# 2  Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# 3  Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# 4  Aupair Aupair Aupair Aupair Aupair Aupair Aupa...

# %% [markdown]
# ### Save

# %%
to_save_path = 'drive/MyDrive/Colab Notebooks/nlp/legal dataset/data/labeled_10_clusters_sz_5.csv'
clustered_topic_df.to_csv(to_save_path)

# %% [markdown]
# # Same for unk clusters amount

# %%
to_read_path = 'drive/MyDrive/Colab Notebooks/nlp/legal dataset/data/25_unk_clusters.csv'
clustered_unk_df = pd.read_csv(to_read_path)
clustered_unk_df = clustered_unk_df[['cluster_id','sentences']]
clustered_unk_df.head()
# Out:
#    cluster_id                                          sentences
# 0          20  It recalls both its own findings and those of ...
# 1          20  This is demonstrated in other cases pending be...
# 2          20  In these circumstances, the Commission finds t...
# 3          20  The Commission finds that the suggested applic...
# 4          20   In this context, the Commission had\r\nregard...

# %%
grouped_unk_df = clustered_unk_df.groupby('cluster_id')
grouped_unk_df.count()
# Out:
#             sentences
# cluster_id
# 0                  50
# 1                  66
# 2                  98
# 3                  72
# 4                  39
# 5                  98
# 6                  96
# 7                  52
# 8                  71
# 9                 119
# 10                 71
# 11                 46
# 12                 98
# 13                 47
# 14                137
# 15                 65
# 16                 78
# 17                 45
# 18                 68
# 19                 15
# 20                 32
# 21                 24
# 22                 29
# 23                 36
# 24                  8

# %%
# %%time

topics = []

for id in range(25):
  result = get_topic(grouped_unk_df.get_group(id)['sentences'].tolist())
  topics.append(result)
  print(result)
# Out:
# 50
# 13
# 4
# The decision by the Court of Appeal to uphold the decision of the High Court to uphold the reservation of a place of worship for Muslims on the M1 motorway is a mixed bag..
# 66
# 17
# 5
# 2
# The Court of Justice of the European Union (CJEU) has upheld a decision by the Court of Justice of the European Union (ECHR) to dismiss an appeal against a decision by the European Court of Human Rights (ECHR) to uphold a ruling by the European Court of Human Rights (ECHR).
# 98
# 25
# 7
# 2
# The European Court of Human Rights (ECHR) has ruled in favour of a Turkish man who was held in pre-trial detention for five years without trial on the grounds that he had received funds from the Turkish government...
# 72
# 18
# 5
# 2
# The European Court of Justice (CJEU) has upheld the decision of the Austrian Supreme Court to reject an appeal by a Bulgarian child killer against a decision by the Austrian Parole Board to release him on parole.
# 39
# 10
# 3
# Amy Winehouse's mother has won a court case against the Turkish authorities over her son's death in police custody.
# 98
# 25
# 7
# 2
# The family of a man who died in custody after being extradited from Azerbaijan have lost a legal bid to stop him leaving the UK.
# 96
# 24
# 6
# 2
# The European Court of Human Rights (ECHR) has ruled in favour of the former mayor of Ersin, Monika Gl, in a case brought against the city by a woman who was injured in a car accident.
# 52
# 13
# 4
# In our series of letters from African journalists, film-maker and columnist Farai Sevenzo considers whether the Constitutional Court has the power to quash an administrative measure.
# 71
# 18
# 5
# 2
# Aupair has won its appeal against a decision by the Director of Public Prosecutions (DPP) not to charge Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair
# 119
# 30
# 8
# 2
# Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair Aupair
# 71
# 18
# 5
# 2
# The Court of Justice of the European Union (CJEU) has upheld the decision of the European Court of Human Rights to dismiss the complaint against the President of the European Commission, Jean-Claude Juncker...
# 46
# 12
# 3
# The European Court of Human Rights has ruled in favour of a third and the fourth applicant in a case brought against the Social Council of the Republic of Ireland over access to social services.
# 98
# 25
# 7
# 2
# Sri Lanka's military court-martial system has been criticised by the European Court of Human Rights.
# 47
# 12
# 3
# The European Court of Human Rights (ECHR) has ruled in a case brought by the European Commission against the French government on the issue of the right of access to justice in France.
# 137
# 35
# 9
# 3
# The Court of Justice of the European Union (CJEU) has upheld the decision of the Court of Justice of the European Union (CJEU) to suspend the custody proceedings in the case of the former Prime Minister, Silvio Berlusconi.
# 65
# 17
# 5
# 2
# The Court of Appeal has rejected a claim for damages by a man who was detained indefinitely after being convicted of possessing indecent images of children.
# 78
# 20
# 5
# 2
# The interrogation of witnesses by the investigating judge is not a substitute for the possibility of the defence questioning the witnesses in their presence and make their judgment as to their demeanour and reliability.
# 45
# 12
# 3
# The decision of the Court of Appeal to uphold the decision of the Secretary of State to publish the report of the Independent Police Complaints Commission into the conduct of the former Home Secretary, Jacqui Smith, and her successor, Charles Clarke, is binding on the Secretary of State.
# 68
# 17
# 5
# 2
# The Gambian government's decision not to prosecute two prominent human rights activists who had been involved in consensual sado-masochistic activities is in line with the Gambian government's decision not to prosecute two prominent human rights activists who had been involved in consensual sado-masochistic activities
# 15
# 4
# The European Commission has taken cognizance of the submissions of the parties in a complaint brought against the European Commission under the European Convention on Human Rights.
# 32
# 8
# 2
# The European Court of Human Rights (ECHR) has ruled in a case brought by a woman that her husband's complaints against the police were not raised at least in substance before the domestic courts.
# 24
# 6
# 2
# The Archbishop of Canterbury's son, Joseph Palaoro, has been granted leave to appeal against the decision of the Magistrates' Court to acquit him of a criminal charge of inebriation.
# 29
# 8
# 2
# The decision by the Swiss authorities to grant a residence permit to the Turkish President, Recep Tayyip Gl, and his wife, Leyla, has raised two important issues.
# 36
# 9
# 3
# The European Commission has rejected a complaint brought by the United States against the European Commission under the Convention on the Rights of the Child.
# 8
# 2
# All photographs are copyrighted.
# CPU times: user 9min 16s, sys: 1.6 s, total: 9min 18s
# Wall time: 9min 19s

# %%
len(topics)
# Out:
# 25

# %%
clustered_topic_unk_df = clustered_unk_df.join(pd.Series(topics)[clustered_unk_df['cluster_id']].to_frame("topic").reset_index())
clustered_topic_unk_df = clustered_topic_unk_df[['cluster_id','sentences','topic']]

# %%
clustered_topic_unk_df
# Out:
#       cluster_id                                          sentences  \
# 0             20  It recalls both its own findings and those of ...
# 1             20  This is demonstrated in other cases pending be...
# 2             20  In these circumstances, the Commission finds t...
# 3             20  The Commission finds that the suggested applic...
# 4             20   In this context, the Commission had\r\nregard...
# ...          ...                                                ...
# 1555          19  The Commission considers, in the light of the ...
# 1556          19  These include the power to quash in all respec...
# 1557          19  that a thorough\r\nexamination of this complai...
# 1558          19  The Commission considers that the applicant's ...
# 1559          19  The Commission has taken cognizance of the sub...
#
#                                                   topic
# 0     The European Court of Human Rights (ECHR) has ...
# 1     The European Court of Human Rights (ECHR) has ...
# 2     The European Court of Human Rights (ECHR) has ...
# 3     The European Court of Human Rights (ECHR) has ...
# 4     The European Court of Human Rights (ECHR) has ...
# ...                                                 ...
# 1555  The European Commission has taken cognizance o...
# 1556  The European Commission has taken cognizance o...
# 1557  The European Commission has taken cognizance o...
# 1558  The European Commission has taken cognizance o...
# 1559  The European Commission has taken cognizance o...
#
# [1560 rows x 3 columns]

# %% [markdown]
# ### Save

# %%
to_save_path = 'drive/MyDrive/Colab Notebooks/nlp/legal dataset/data/labeled_25_unk_clusters_sz_4.csv'
clustered_topic_unk_df.to_csv(to_save_path)

# %% [markdown]
# # Explore results

# %%
to_read_path = 'drive/MyDrive/Colab Notebooks/nlp/legal dataset/data/labeled_10_clusters_sz_5.csv'
clustered_topic_df = pd.read_csv(to_read_path).drop(columns=['Unnamed: 0'])
clustered_topic_df
# Out:
#       cluster_id                                          sentences  \
# 0              2  It recalls both its own findings and those of ...
# 1              2  This is demonstrated in other cases pending be...
# 2              2  Publication was also necessary to protect the ...
# 3              2  In the present case,\r\nthere was a formidable...
# 4              2  It was therefore not empowered to take evidenc...
# ...          ...                                                ...
# 1555           8  However, the fact complained of relates to a p...
# 1556           8  The\r\napplicant refers here in particular to ...
# 1557           8   It is to be observed that a crucial issue in ...
# 1558           8  In 1988, when considering certain amendments t...
# 1559           8  The Commission recalls that any complaints abo...
#
#                                                   topic
# 0     Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# 1     Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# 2     Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# 3     Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# 4     Aupair Aupair Aupair Aupair Aupair Aupair Aupa...
# ...                                                 ...
# 1555  The European Court of Human Rights (ECHR) has ...
# 1556  The European Court of Human Rights (ECHR) has ...
# 1557  The European Court of Human Rights (ECHR) has ...
# 1558  The European Court of Human Rights (ECHR) has ...
# 1559  The European Court of Human Rights (ECHR) has ...
#
# [1560 rows x 3 columns]

# %%
to_read_path = 'drive/MyDrive/Colab Notebooks/nlp/legal dataset/data/labeled_25_unk_clusters_sz_4.csv'
clustered_topic_unk_df = pd.read_csv(to_read_path).drop(columns=['Unnamed: 0'])
clustered_topic_unk_df
# Out:
#       cluster_id                                          sentences  \
# 0             20  It recalls both its own findings and those of ...
# 1             20  This is demonstrated in other cases pending be...
# 2             20  In these circumstances, the Commission finds t...
# 3             20  The Commission finds that the suggested applic...
# 4             20   In this context, the Commission had\r\nregard...
# ...          ...                                                ...
# 1555          19  The Commission considers, in the light of the ...
# 1556          19  These include the power to quash in all respec...
# 1557          19  that a thorough\r\nexamination of this complai...
# 1558          19  The Commission considers that the applicant's ...
# 1559          19  The Commission has taken cognizance of the sub...
#
#                                                   topic
# 0     The European Court of Human Rights (ECHR) has ...
# 1     The European Court of Human Rights (ECHR) has ...
# 2     The European Court of Human Rights (ECHR) has ...
# 3     The European Court of Human Rights (ECHR) has ...
# 4     The European Court of Human Rights (ECHR) has ...
# ...                                                 ...
# 1555  The European Commission has taken cognizance o...
# 1556  The European Commission has taken cognizance o...
# 1557  The European Commission has taken cognizance o...
# 1558  The European Commission has taken cognizance o...
# 1559  The European Commission has taken cognizance o...
#
# [1560 rows x 3 columns]

# %%
clustered_topic_unk_df['cluster_id'].min()
# Out:
# 0

# %%
clustered_topic_unk_df['cluster_id'].max()
# Out:
# 24

# %%
clustered_topic_df['cluster_id'].min()
# Out:
# 0

# %%
clustered_topic_df['cluster_id'].max()
# Out:
# 9

# %%
def print_row(i):
  entry = clustered_topic_unk_df.iloc[i]
  print('   Sentences')
  print(entry['sentences'])
  print('   Topic')
  print(entry['topic'])

# %%
print_row(12)
# Out:
#    Sentences
# In this
# respect, they refer to the numerous other matters related to the
# proceedings at issue, and the proceedings before the Vienna Juvenile
# Court.
#    Topic
# The European Court of Human Rights (ECHR) has ruled in a case brought by a woman that her husband's complaints against the police were not raised at least in substance before the domestic courts.

# %%
clustered_topic_unk_df
# Out:
#       cluster_id                                          sentences  \
# 0             20  It recalls both its own findings and those of ...
# 1             20  This is demonstrated in other cases pending be...
# 2             20  In these circumstances, the Commission finds t...
# 3             20  The Commission finds that the suggested applic...
# 4             20   In this context, the Commission had\r\nregard...
# ...          ...                                                ...
# 1555          19  The Commission considers, in the light of the ...
# 1556          19  These include the power to quash in all respec...
# 1557          19  that a thorough\r\nexamination of this complai...
# 1558          19  The Commission considers that the applicant's ...
# 1559          19  The Commission has taken cognizance of the sub...
#
#                                                   topic
# 0     The European Court of Human Rights (ECHR) has ...
# 1     The European Court of Human Rights (ECHR) has ...
# 2     The European Court of Human Rights (ECHR) has ...
# 3     The European Court of Human Rights (ECHR) has ...
# 4     The European Court of Human Rights (ECHR) has ...
# ...                                                 ...
# 1555  The European Commission has taken cognizance o...
# 1556  The European Commission has taken cognizance o...
# 1557  The European Commission has taken cognizance o...
# 1558  The European Commission has taken cognizance o...
# 1559  The European Commission has taken cognizance o...
#
# [1560 rows x 3 columns]
